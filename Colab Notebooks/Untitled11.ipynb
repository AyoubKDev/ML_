# %%
import pandas as pd

df = pd.read_csv('/content/tested.csv')

#print df to check
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
selected_columns = ["Survived", "Age", "Fare","Sex","Pclass"]
selected_df = df[selected_columns]
selected_df
# Out:
#      Survived   Age      Fare     Sex  Pclass
# 0           0  34.5    7.8292    male       3
# 1           1  47.0    7.0000  female       3
# 2           0  62.0    9.6875    male       2
# 3           0  27.0    8.6625    male       3
# 4           1  22.0   12.2875  female       3
# ..        ...   ...       ...     ...     ...
# 413         0   NaN    8.0500    male       3
# 414         1  39.0  108.9000  female       1
# 415         0  38.5    7.2500    male       3
# 416         0   NaN    8.0500    male       3
# 417         0   NaN   22.3583    male       3
#
# [418 rows x 5 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Convert "Sex" column to a categorical type
df["Sex"] = pd.Categorical(df["Sex"])

# Assign category codes (0 for female, 1 for male)
df["Sex"] = df["Sex"].cat.codes
df
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)    0  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...    0  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    0  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild    0  22.0      0
# 28                             Brady, Mr. John Bertram    1  41.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
# Separate features and target
X = df[["Pclass", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]]
y = df["Survived"]

# Check the dimensions
print(f"Features (X) shape: {X.shape}")
print(f"Target (y) shape: {y.shape}")
# Out:
# Features (X) shape: (87, 9)
# Target (y) shape: (87,)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.neighbors import KNeighborsClassifier


# Stratified sampling to ensure balanced class distribution in splits
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=1)

# Get training and testing indices
train_index, test_index = next(iter(sss.split(X, y)))

# Split data using indices
X_train, X_test = X.iloc[train_index], X.iloc[test_index]
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# Create a KNeighborsClassifier with distance metric optimization
knn = KNeighborsClassifier(metric='manhattan')
knn
# Train the model
knn.fit(X_train, y_train)

# Make predictions
y_pred = knn.predict(X_test)

# Evaluate the model (e.g., accuracy)
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-228ecaf6cd2a> in <cell line: 19>()
#      17 knn
#      18 # Train the model
# ---> 19 knn.fit(X_train, y_train)
#      20
#      21 # Make predictions
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
#     455                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     456                 )
#
# ...
