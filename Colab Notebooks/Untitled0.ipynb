# %%
# !git clone https://github.com/aimacode/aima-python.git
# Out:
# Cloning into 'aima-python'...
# remote: Enumerating objects: 5095, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5095 (delta 0), reused 1 (delta 0), pack-reused 5092
# Receiving objects: 100% (5095/5095), 17.71 MiB | 25.86 MiB/s, done.
# Resolving deltas: 100% (3416/3416), done.

# %%
# %cd aima-python
# Out:
# /content/aima-python

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 KB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 64.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 KB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 KB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 KB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 KB 12.7 MB/s eta 0:00:00
# ...
#   Created wheel for image: filename=image-1.5.33-py2.py3-none-any.whl size=19497 sha256=80add0738e7b2b8204ebf79f18cd680068fa3443f1f6f41734e5fcba9bd1100c
#   Stored in directory: /root/.cache/pip/wheels/14/4c/7c/d9b5c35a149d3bc8c72c7e92372913ff7dac9c6bd94bd1b8c9
# ...

# %%
# !git submodule init
# Out:
# Submodule 'aima-data' (https://github.com/aimacode/aima-data.git) registered for path 'aima-data'

# %%
# !git submodule update
# Out:
# Cloning into '/content/aima-python/aima-data'...
# Submodule path 'aima-data': checked out 'f6cbea61ad0c21c6b7be826d17af5a8d3a7c2c86'

# %%
from utils import *

# %%
from logic import *

# %%
# !pip install aima 
from aima.logic import * 

from aima.utils import *

fc=FolKB()
pc=PropKB()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
(Student,p1) = symbols("student,p1")

# %%
expr("Student(p1)")
# Out:
# Student(p1)

# %%
(grandfather,father,p1,p2,p3,ahmed,mohamed) = symbols("grandfather,father,p1,p2,p3,ahmed,mohamed")
fc.tell(expr("Father(p1,p2) & Father(p2,p3) ==> GrandFather(p1,p3)"))

# %%
expr(father(ahmed,mohamed))
# Out:
# father(ahmed, mohamed)

# %%
fc.tell(expr("Father(Ahmed,Mohamed)"))

# %%
fc.ask(expr("father(Ahmed,Mohamed)"))
# Out:
# False

# %%
fc.ask(expr("Father(Ahmd,Ahmed)"))
# Out:
# False

# %%
fc.clauses
# Out:
# [Father(Mohamed, Ahmed)]

# %%
fc.retract(expr("Father(Ahmed,Mohamed)"))

# %%
fc.tell(expr("Father(Mohamed,Ahmed)"))

# %%
fc.tell(expr("Father(Ahmed,Fathi)"))

# %%
fc.ask(expr("Father(Ahmed,Mohamed)"))
# Out:
# False

# %%
fc.ask(expr("GrandFather(Mohamed,Fathi)"))
# Out:
# {v_68: Mohamed, v_70: Fathi, v_69: Ahmed}

# %%
(x,y) = symbols("x,y")

# %%
fc.tell(expr("Fem(x) & Parent(x,y) ==> Mere(x,y)"))

# %%
fc.tell(expr("Masculin(x) & Parent(x,y) ==> Pere(x,y)"))

# %%
fc.tell(expr("Masculin(Mohamed)"))

# %%
fc.tell(expr("Parent(Mohamed,Ahmed)"))

# %%
fc.ask(expr("Mere(Mohamed,Ahmed)"))
# Out:
# False

# %%
fc.ask(expr("Pere(Mohamed,Ahmed)"))
# Out:
# {v_45089: Mohamed, v_45090: Ahmed}

# %%
fc.tell(expr("Parent(x,y) & Parent(x,z) ==> Frere(y,z) "))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-21-616ff37a3d4b> in <module>
# ----> 1 fc.tell(expr("Parent(x,y) & Parent(x,z) ==> Frere(y,z) & Frere(y,z)"))
#
# /usr/local/lib/python3.9/dist-packages/aima/logic.py in tell(self, sentence)
#    1941             self.clauses.append(sentence)
#    1942         else:
# -> 1943             raise Exception('Not a definite clause: {}'.format(sentence))
#    1944
#    1945     def ask_generator(self, query):
#
# Exception: Not a definite clause: ((Parent(x, y) & Parent(x, z)) ==> (Frere(y, z) & Frere(y, z)))

# %%
fc.tell(expr("Parent(Mohamed,Zakaria)"))
fc.tell(expr("Parent(Mohamed,Ayoub)"))

# %%
fc.ask(expr("Frere(Zakaria,Ayoub)"))
# Out:
# {v_45104: Zakaria, v_45105: Ayoub, v_45103: Mohamed}

# %%
fc.tell(expr("Parent(x,y) & Frere(x,z) ==> Uncle(z,y)"))

# %%
fc.tell(expr("Parent(Mohamed,Youcef)"))
fc.tell(expr("Frere(Mohamed,Ahmed)"))

# %%
p = fc.ask(expr("Uncle(x,Youcef)"))

# %%
p[x]
# Out:
# Ahmed

# %%
fc.ask(expr("Uncle(x,Omar)"))
# Out:
# False

# %%
fc.tell(expr("Parent(x,y) ==> Ancestor(x,y)"))
fc.tell(expr("Parent(x,y) & Ancestor(y,z) ==> Ancestor(x,z)"))

# %%
fc.tell(expr("~",expr("A(x)")))
fc.tell(expr("A(x) & B(y) ==> C(x,y)"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-f87e61410a82> in <module>
# ----> 1 fc.tell(expr("~",expr("A(x)")))
#       2 fc.tell(expr("A(x) & B(y) ==> C(x,y)"))
#
# TypeError: expr() takes 1 positional argument but 2 were given

# %%
fc.tell(expr("Parent(Jean,Fabien)"))
fc.tell(expr("Parent(Fabien,Louise)"))
fc.tell(expr("Parent(Louise,Jerome)"))
fc.tell(expr("Parent(Jerome,Franck)"))

# %%
result = list(fol_fc_ask(fc,expr("Ancestor(x,Franck)")))

# %%
for x in range(len(result)):
  print(result)

# %%
print(result)
# Out:
# []

# %%
result = list(fol_fc_ask(fc,expr("Ancestor(Franck,Fabien)")))

# %%
print(result)
# Out:
# []

# %%
fc.tell(expr("Adj(x,y) & Diff(z,w) ==> Coloriage(x,z) & Coloriage(y,w) "))
fc.tell(expr("Diff(Blue,Vert)"))
fc.tell(expr("Diff(Blue,Blanc)"))
fc.tell(expr("Diff(Blue,Noir)"))
fc.tell(expr("Diff(Blanc,Vert)"))
fc.tell(expr("Diff(Noir,Vert)"))
fc.tell(expr("Diff(Blanc,Noir)"))
fc.tell(expr("Couleur(Blue)"))
fc.tell(expr("Couleur(Blanc)"))
fc.tell(expr("Couleur(Noir)"))
fc.tell(expr("Couleur(Vert)"))

fc.tell(expr("Adj(C1,C2)"))
fc.tell(expr("Adj(C1,C3)"))
fc.tell(expr("Adj(C1,C4)"))
fc.tell(expr("Adj(C1,C5)"))
fc.tell(expr("Adj(C1,C6)"))
fc.tell(expr("Adj(C2,C3)"))
fc.tell(expr("Adj(C2,C4)"))
fc.tell(expr("Adj(C2,C5)"))
fc.tell(expr("Adj(C2,C6)"))
fc.tell(expr("Adj(C4,C3)"))
fc.tell(expr("Adj(C6,C5)"))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-19-6a55b31541d6> in <module>
# ----> 1 fc.tell(expr("Adj(x,y) & Diff(z,w) ==> Coloriage(x,z) & Coloriage(y,w) "))
#       2 fc.tell(expr("Diff(Blue,Vert)"))
#       3 fc.tell(expr("Diff(Blue,Blanc)"))
#       4 fc.tell(expr("Diff(Blue,Noir)"))
#       5 fc.tell(expr("Diff(Blanc,Vert)"))
#
# /usr/local/lib/python3.9/dist-packages/aima/logic.py in tell(self, sentence)
#    1941             self.clauses.append(sentence)
#    1942         else:
# -> 1943             raise Exception('Not a definite clause: {}'.format(sentence))
#    1944
#    1945     def ask_generator(self, query):
#
# Exception: Not a definite clause: ((Adj(x, y) & Diff(z, w)) ==> (Coloriage(x, z) & Coloriage(y, w)))

# %%
fc.tell(expr(""))
