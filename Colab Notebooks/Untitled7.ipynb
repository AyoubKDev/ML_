# %%
import pandas as pd
dataset = pd.read_csv("/content/sample_data/ratings_Beauty.csv")
print("Columns:", dataset.columns)
print("Number of Rows:", len(dataset))
statistics = dataset.describe()
print("Averaged Numbers, Max/Min Values:\n", statistics)
missing_values = dataset.isna().sum()
print("Number of Missing Values per Column:\n", missing_values)
# Out:
# Columns: Index(['UserId', 'ProductId', 'Rating', 'Timestamp'], dtype='object')
# Number of Rows: 205885
# Averaged Numbers, Max/Min Values:
#                Rating     Timestamp
# count  205885.000000  2.058850e+05
# mean        4.176244  1.333325e+09
# std         1.324857  7.209881e+07
# min         1.000000  1.303948e+06
# 25%         4.000000  1.305504e+09
# 50%         5.000000  1.360454e+09
# 75%         5.000000  1.384646e+09
# max         5.000000  1.406074e+09
# Number of Missing Values per Column:
#  UserId       0
# ProductId    0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
dataset.sort_values(by=['ProductId'], ascending=False)
# Out:
#                 UserId   ProductId  Rating   Timestamp
# 205884  A1VC4AO4P4XT82  B000C1ZEJE     5.0     1303948
# 205877  A2WX75G2W9TKEN  B000C1ZEJE     1.0  1400803200
# 205870  A2T9ZW8DJJVSXN  B000C1ZEJE     5.0  1320710400
# 205871  A1SO1IRY3WQSL5  B000C1ZEJE     5.0  1393632000
# 205872   AWTRHIVUWT8J5  B000C1ZEJE     5.0  1400198400
# ...                ...         ...     ...         ...
# 4       A3IAAVS479H7M7  0737104473     1.0  1274227200
# 3       A1WMRR494NWEWV  0733001998     4.0  1382572800
# 2       A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 1       A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 0       A39HTATAQ9V7YF  0205616461     5.0  1369699200
#
# [205885 rows x 4 columns]

# %%
grouper = pd.Grouper(key='Timestamp', freq='D')

# Apply the Grouper object to the dataset
grouped_dataset = dataset.groupby('Timestamp')

# Extract the size attribute of the Grouper object, which contains the number of rows in each group
days = grouped_dataset.size()

# Add a new column to the dataset containing the days
dataset['days'] = days
dataset
# Save the updated dataset
#df.to_csv('updated_dataset.csv', index=False)
# Out:
#                 UserId   ProductId  Rating   Timestamp  days
# 0       A39HTATAQ9V7YF  0205616461     5.0  1369699200   NaN
# 1       A3JM6GV9MNOF9X  0558925278     3.0  1355443200   NaN
# 2       A1Z513UWSAAO0F  0558925278     5.0  1404691200   NaN
# 3       A1WMRR494NWEWV  0733001998     4.0  1382572800   NaN
# 4       A3IAAVS479H7M7  0737104473     1.0  1274227200   NaN
# ...                ...         ...     ...         ...   ...
# 205880  A39KC6PJKJ3OJU  B000C1ZEJE     5.0  1241740800   NaN
# 205881  A1K8SL6CWH587I  B000C1ZEJE     5.0  1355875200   NaN
# 205882   ANXBSUZARW3XU  B000C1ZEJE     5.0  1391385600   NaN
# 205883   AANC63UW51Z5J  B000C1ZEJE     5.0  1377907200   NaN
# 205884  A1VC4AO4P4XT82  B000C1ZEJE     5.0     1303948   NaN
#
# [205885 rows x 5 columns]
