# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# Load the dataset
df = pd.read_csv('/content/datasetCovid.csv',encoding='latin1')
df
# Form Analysis
# 1. Target Variable Analysis
target_variable = 'SARS-Cov-2 exam result'

# 2. Identify Rows and Columns
num_rows, num_columns = df.shape

# 3. Variable Types
variable_types = df.dtypes
print("variable types : ",variable_types)
# 4. Missing Values Analysis
missing_values = df.isnull().sum()

# Background Analysis
# 1. Target Visualization
sns.countplot(x=target_variable, data=df)
plt.title('Distribution of SARS-Cov-2 exam result')
plt.show()

# 2. Variable Significance
# You may want to explore individual features based on domain knowledge

# 3. Variable-Target Relationship
# For example, let's consider Hematocrit
sns.boxplot(x=target_variable, y='Hematocrit', data=df)
plt.title('Hematocrit vs SARS-Cov-2 exam result')
plt.show()

# Data Cleaning
from sklearn.impute import SimpleImputer

# Assuming X has both numerical and categorical features
numerical_features = X.select_dtypes(include=['float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# Impute missing values for numerical features
numerical_imputer = SimpleImputer(strategy='mean')  # You can choose a different strategy if needed

# Fit and transform the imputer on numerical features
X[numerical_features] = numerical_imputer.fit_transform(X[numerical_features])

# Impute missing values for categorical features
categorical_imputer = SimpleImputer(strategy='most_frequent')  # You can choose a different strategy if needed

# Fit and transform the imputer on categorical features
X[categorical_features] = categorical_imputer.fit_transform(X[categorical_features])


# Model Building


# Make predictions and evaluate the model...


# Make predictions and evaluate the model...

#
## Make predictions
#y_pred = model.predict(X_test)
#
## Evaluate the model
#accuracy = accuracy_score(y_test, y_pred)
#conf_matrix = confusion_matrix(y_test, y_pred)
#class_report = classification_report(y_test, y_pred)
#
#print(f'Accuracy: {accuracy}')
#print(f'Confusion Matrix:\n{conf_matrix}')
#print(f'Classification Report:\n{class_report}')
# Out:
# variable types :  Patient ID                                                object
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
#                                                           ...
# HCO3 (arterial blood gas analysis)                       float64
# pO2 (arterial blood gas analysis)                        float64
# Arteiral Fio2                                            float64
# Phosphor                                                 float64
# ctO2 (arterial blood gas analysis)                       float64
# Length: 111, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-056f42e49a2f> in <cell line: 51>()
# ...
